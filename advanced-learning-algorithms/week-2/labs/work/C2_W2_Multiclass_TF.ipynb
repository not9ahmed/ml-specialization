# %% [markdown]
# # Optional Lab - Multi-class Classification

# %% [markdown]
# ## 1.1 Goals
# In this lab, you will explore an example of multi-class classification using neural networks.
# <figure>
#  <img src="./images/C2_W2_mclass_header.png"   style="width500px;height:200px;">
# </figure>

# %% [markdown]
# ## 1.2 Tools
# You will use some plotting routines. These are stored in `lab_utils_multiclass_TF.py` in this directory.

# %%
# importing numpy and matplot
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget

# importing sk learn datatsets which generate sample datasets
from sklearn.datasets import make_blobs

# import tensorflow Sequential, Dense
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# choosing 0.00 precision
np.set_printoptions(precision=2)

# importing lab methods and adding the loggers
from lab_utils_multiclass_TF import *
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
tf.autograph.set_verbosity(0)

# %% [markdown]
# # 2.0 Multi-class Classification
# Neural Networks are often used to classify data. Examples are neural networks:
# - take in photos and classify subjects in the photos as {dog,cat,horse,other}
# - take in a sentence and classify the 'parts of speech' of its elements: {noun, verb, adjective etc..}
#
# A network of this type will have multiple units in its final layer. Each output is associated with a category. When an input example is applied to the network, the output with the highest value is the category predicted. If the output is applied to a softmax function, the output of the softmax will provide probabilities of the input being in each category.
#
# In this lab you will see an example of building a multiclass network in Tensorflow. We will then take a look at how the neural network makes its predictions.
#
# Let's start by creating a four-class data set.

# %% [markdown]
# ## 2.1 Prepare and visualize our data
# We will use Scikit-Learn `make_blobs` function to make a training data set with 4 categories as shown in the plot below.

# %%
# make 4-class dataset for classification
classes = 4

# m is number of training examples
m = 100

# setting the specificifation of the dataset clusters
centers = [[-5, 2], [-2, -2], [1, 2], [5, -2]]
std = 1.0

# will generate a sample dataset
X_train, y_train = make_blobs(n_samples=m, centers=centers, cluster_std=std,random_state=30)

# %%
# will plot a sample dataset with 4 classes
plt_mc(X_train,y_train,classes, centers, std=std)
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# Each dot represents a training example. The axis (x0,x1) are the inputs and the color represents the class the example is associated with. Once trained, the model will be presented with a new example, (x0,x1), and will predict the class.
#
# While generated, this data set is representative of many real-world classification problems. There are several input features (x0,...,xn) and several output categories. The model is trained to use the input features to predict the correct output category.

# %%
# show classes in data set
print(f"unique classes {np.unique(y_train)}")



# show how classes are represented
# print y_trail until the 10th example
print(f"class representation {y_train[:10]}")


# show shapes of our dataset
# 100 examples, 2 features
print(f"shape of X_train: {X_train.shape}, shape of y_train: {y_train.shape}")
# Out:
# unique classes [0 1 2 3]
# class representation [3 3 3 0 3 3 3 3 2 0]
# shape of X_train: (100, 2), shape of y_train: (100,)

# %% [markdown]
# ## 2.2 Model
# <img align="Right" src="./images/C2_W2_mclass_lab_network.PNG"  style=" width:350px; padding: 10px 20px ; ">
# This lab will use a 2-layer network as shown.
# Unlike the binary classification networks, this network has four outputs, one for each class. Given an input example, the output with the highest value is the predicted class of the input.
#
# Below is an example of how to construct this network in Tensorflow. Notice the output layer uses a `linear` rather than a `softmax` activation. While it is possible to include the softmax in the output layer, it is more numerically stable if linear outputs are passed to the loss function during training. If the model is used to predict probabilities, the softmax can be applied at that point.

# %%
tf.random.set_seed(1234)  # applied to achieve consistent results

# defining the model with 2 layers
# layer 1 relu, hidden layer, has 2 units
# layer 2 lineae, output layer, has 4 units for each class,
# we're using linear to avoid round off problem,
# but will use softmax during the prediction process
model = Sequential(
    [
        Dense(2, activation = 'relu',   name = "L1"),
        Dense(4, activation = 'linear', name = "L2")
    ]
)
# Out:
# Metal device set to: Apple M1
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB
# 2024-02-20 20:46:11.846196: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-20 20:46:11.847494: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# The statements below compile and train the network. Setting `from_logits=True` as an argument to the loss function specifies that the output activation was linear rather than a softmax.

# %%
# specifying the loss function
# loss will be SparseCategoricalCrossentropy (Softmax)
# (from_logits=True) means linear values will be passed
# adam is optimzer type/ just like gradient descne

model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(0.01),
)

# training the model given the dataset
# 200 epochs/ times running on the dataset
model.fit(
    X_train,y_train,
    epochs=200
)
# Out:
# 2024-02-20 20:51:03.821507: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Epoch 1/200
# 2024-02-20 20:51:04.117740: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 4/4 [==============================] - 2s 26ms/step - loss: 1.4589
# Epoch 2/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3763
# Epoch 3/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3197
# Epoch 4/200
# 4/4 [==============================] - 0s 8ms/step - loss: 1.2697
# Epoch 5/200
# 4/4 [==============================] - 0s 8ms/step - loss: 1.2220
# Epoch 6/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1724
# Epoch 7/200
# 4/4 [==============================] - 0s 16ms/step - loss: 1.1210
# Epoch 8/200
# 4/4 [==============================] - 0s 8ms/step - loss: 1.0654
# Epoch 9/200
# 4/4 [==============================] - 0s 8ms/step - loss: 1.0143
# Epoch 10/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.9588
# Epoch 11/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.9130
# Epoch 12/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.8703
# Epoch 13/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.8348
# Epoch 14/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.8002
# Epoch 15/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7696
# Epoch 16/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7430
# Epoch 17/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7187
# Epoch 18/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6946
# Epoch 19/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6733
# Epoch 20/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6531
# Epoch 21/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6343
# Epoch 22/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6172
# Epoch 23/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6011
# Epoch 24/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5866
# Epoch 25/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5720
# Epoch 26/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5581
# Epoch 27/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5453
# Epoch 28/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5323
# Epoch 29/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5193
# Epoch 30/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5057
# Epoch 31/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4926
# Epoch 32/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4798
# Epoch 33/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4660
# Epoch 34/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4536
# Epoch 35/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4408
# Epoch 36/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4284
# Epoch 37/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4146
# Epoch 38/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4016
# Epoch 39/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3895
# Epoch 40/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3770
# Epoch 41/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3650
# Epoch 42/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3537
# Epoch 43/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3427
# Epoch 44/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3315
# Epoch 45/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3208
# Epoch 46/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3107
# Epoch 47/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3005
# Epoch 48/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2910
# Epoch 49/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2814
# Epoch 50/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2725
# Epoch 51/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2640
# Epoch 52/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2556
# Epoch 53/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2476
# Epoch 54/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2392
# Epoch 55/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2315
# Epoch 56/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2238
# Epoch 57/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2165
# Epoch 58/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2097
# Epoch 59/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2026
# Epoch 60/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1953
# Epoch 61/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1887
# Epoch 62/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1824
# Epoch 63/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1763
# Epoch 64/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1700
# Epoch 65/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1647
# Epoch 66/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1587
# Epoch 67/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1533
# Epoch 68/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1481
# Epoch 69/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1434
# Epoch 70/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1392
# Epoch 71/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1349
# Epoch 72/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1313
# Epoch 73/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1269
# Epoch 74/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1233
# Epoch 75/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1198
# Epoch 76/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1168
# Epoch 77/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1139
# Epoch 78/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1106
# Epoch 79/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1076
# Epoch 80/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1046
# Epoch 81/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1020
# Epoch 82/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0994
# Epoch 83/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0972
# Epoch 84/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0948
# Epoch 85/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0925
# Epoch 86/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0904
# Epoch 87/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0879
# Epoch 88/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0859
# Epoch 89/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0837
# Epoch 90/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0819
# Epoch 91/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0801
# Epoch 92/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0784
# Epoch 93/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0770
# Epoch 94/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0753
# Epoch 95/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0737
# Epoch 96/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0724
# Epoch 97/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0709
# Epoch 98/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0696
# Epoch 99/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0684
# Epoch 100/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0670
# Epoch 101/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0658
# Epoch 102/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0647
# Epoch 103/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0635
# Epoch 104/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0626
# Epoch 105/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0611
# Epoch 106/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0599
# Epoch 107/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0589
# Epoch 108/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0578
# Epoch 109/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0567
# Epoch 110/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0558
# Epoch 111/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0549
# Epoch 112/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0541
# Epoch 113/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0532
# Epoch 114/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0524
# Epoch 115/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0516
# Epoch 116/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0508
# Epoch 117/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0503
# Epoch 118/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0494
# Epoch 119/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0486
# Epoch 120/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0482
# Epoch 121/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0475
# Epoch 122/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0468
# Epoch 123/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0461
# Epoch 124/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0454
# Epoch 125/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0448
# Epoch 126/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0441
# Epoch 127/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0436
# Epoch 128/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0430
# Epoch 129/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0425
# Epoch 130/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0418
# Epoch 131/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0415
# Epoch 132/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0409
# Epoch 133/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0404
# Epoch 134/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0399
# Epoch 135/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0394
# Epoch 136/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0389
# Epoch 137/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0385
# Epoch 138/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0380
# Epoch 139/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0376
# Epoch 140/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0370
# Epoch 141/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0365
# Epoch 142/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0360
# Epoch 143/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0356
# Epoch 144/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0352
# Epoch 145/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0348
# Epoch 146/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0343
# Epoch 147/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0339
# Epoch 148/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0336
# Epoch 149/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0333
# Epoch 150/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0331
# Epoch 151/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0330
# Epoch 152/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0327
# Epoch 153/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0323
# Epoch 154/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0318
# Epoch 155/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0313
# Epoch 156/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0309
# Epoch 157/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0304
# Epoch 158/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0301
# Epoch 159/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0298
# Epoch 160/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0295
# Epoch 161/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0291
# Epoch 162/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0288
# Epoch 163/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0284
# Epoch 164/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0281
# Epoch 165/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0279
# Epoch 166/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0276
# Epoch 167/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0273
# Epoch 168/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0271
# Epoch 169/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0268
# Epoch 170/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0265
# Epoch 171/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0262
# Epoch 172/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0260
# Epoch 173/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0260
# Epoch 174/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0258
# Epoch 175/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0255
# Epoch 176/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0250
# Epoch 177/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0248
# Epoch 178/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0245
# Epoch 179/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0246
# Epoch 180/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0242
# Epoch 181/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0238
# Epoch 182/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0236
# Epoch 183/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0235
# Epoch 184/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0233
# Epoch 185/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0229
# Epoch 186/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0227
# Epoch 187/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0226
# Epoch 188/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0224
# Epoch 189/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0222
# Epoch 190/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0221
# Epoch 191/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0219
# Epoch 192/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0217
# Epoch 193/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0215
# Epoch 194/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0213
# Epoch 195/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0210
# Epoch 196/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0209
# Epoch 197/200
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0206
# Epoch 198/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0204
# Epoch 199/200
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0203
# Epoch 200/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0201

# %% [markdown]
# With the model trained, we can see how the model has classified the training data.

# %%
plt_cat_mc(X_train, y_train, model, classes)
# Out:
# 2024-02-20 20:51:28.891430: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# Above, the decision boundaries show how the model has partitioned the input space.  This very simple model has had no trouble classifying the training data. How did it accomplish this? Let's look at the network in more detail.
#
# Below, we will pull the trained weights from the model and use that to plot the function of each of the network units. Further down, there is a more detailed explanation of the results. You don't need to know these details to successfully use neural networks, but it may be helpful to gain more intuition about how the layers combine to solve a classification problem.

# %%
# gather the trained parameters from the first layer
l1 = model.get_layer("L1")

# returns list with weights (W, b)
W1,b1 = l1.get_weights()

# %%
# plot the function of the first layer
plt_layer_relu(X_train, y_train.reshape(-1,), W1, b1, classes)
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
# gather the trained parameters from the output layer
l2 = model.get_layer("L2")
W2, b2 = l2.get_weights()


# create the 'new features', the training examples after L1 transformation
# f(x) = W * X + b
# = W1 * X_train + b1
Xl2 = np.maximum(0, np.dot(X_train,W1) + b1)


# plot the output layer which is linear given some parameters
plt_output_layer_linear(Xl2, y_train.reshape(-1,), W2, b2, classes,
                        x0_rng = (-0.25,np.amax(Xl2[:,0])), x1_rng = (-0.25,np.amax(Xl2[:,1])))
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# ## Explanation
# #### Layer 1 <img align="Right" src="./images/C2_W2_mclass_layer1.png"  style=" width:600px; padding: 10px 20px ; ">
# These plots show the function of Units 0 and 1 in the first layer of the network. The inputs are ($x_0,x_1$) on the axis. The output of the unit is represented by the color of the background. This is indicated by the color bar on the right of each graph. Notice that since these units are using a ReLu, the outputs do not necessarily fall between 0 and 1 and in this case are greater than 20 at their peaks.
# The contour lines in this graph show the transition point between the output, $a^{[1]}_j$ being zero and non-zero. Recall the graph for a ReLu :<img align="right" src="./images/C2_W2_mclass_relu.png"  style=" width:200px; padding: 10px 20px ; "> The contour line in the graph is the inflection point in the ReLu.
#
# Unit 0 has separated classes 0 and 1 from classes 2 and 3. Points to the left of the line (classes 0 and 1) will output zero, while points to the right will output a value greater than zero.
# Unit 1 has separated classes 0 and 2 from classes 1 and 3. Points above the line (classes 0 and 2 ) will output a zero, while points below will output a value greater than zero. Let's see how this works out in the next layer!

# %% [markdown]
# #### Layer 2, the output layer  <img align="Right" src="./images/C2_W2_mclass_layer2.png"  style=" width:600px; padding: 10px 20px ; ">
#
# The dots in these graphs are the training examples translated by the first layer. One way to think of this is the first layer has created a new set of features for evaluation by the 2nd layer. The axes in these plots are the outputs of the previous layer $a^{[1]}_0$ and $a^{[1]}_1$. As predicted above, classes 0 and 1 (blue and green) have  $a^{[1]}_0 = 0$ while classes 0 and 2 (blue and orange) have $a^{[1]}_1 = 0$.
# Once again, the intensity of the background color indicates the highest values.
# Unit 0 will produce its maximum value for values near (0,0), where class 0 (blue) has been mapped.
# Unit 1 produces its highest values in the upper left corner selecting class 1 (green).
# Unit 2 targets the lower right corner where class 2 (orange) resides.
# Unit 3 produces its highest values in the upper right selecting our final class (purple).
#
# One other aspect that is not obvious from the graphs is that the values have been coordinated between the units. It is not sufficient for a unit to produce a maximum value for the class it is selecting for, it must also be the highest value of all the units for points in that class. This is done by the implied softmax function that is part of the loss function (`SparseCategoricalCrossEntropy`). Unlike other activation functions, the softmax works across all the outputs.
#
# You can successfully use neural networks without knowing the details of what each unit is up to. Hopefully, this example has provided some intuition about what is happening under the hood.

# %% [markdown]
# ## Congratulations!
# You have learned to build and operate a neural network for multiclass classification.
